# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('Transport.csv')
df
# Out:
#      Age  Gender  Engineer  MBA  Work Exp  Salary  Distance  license  \
# 0     28    Male       0.0    0       4.0    14.3       3.2      0.0
# 1     23  Female       1.0    0       4.0     8.3       3.3      0.0
# 2     29    Male       1.0    0       7.0    13.4       4.1      0.0
# 3     28  Female       1.0    1       5.0    13.4       4.5      0.0
# 4     27    Male       1.0    0       4.0    13.4       4.6      0.0
# ..   ...     ...       ...  ...       ...     ...       ...      ...
# 439   40    Male       1.0    0      20.0    57.0      21.4      1.0
# 440   38    Male       1.0    0      19.0    44.0      21.5      1.0
# 441   37    Male       1.0    0      19.0    45.0      21.5      1.0
# 442   37    Male       0.0    0      19.0    47.0      22.8      1.0
# 443   39    Male       1.0    1      21.0    50.0      23.4      1.0
#
#              Transport
# 0     Public Transport
# 1     Public Transport
# 2     Public Transport
# 3     Public Transport
# ...

# %% [markdown]
# # Data Exploration(head,shape,info,dtypes,describe)

# %%
df.head()
# Out:
#    Age  Gender  Engineer  MBA  Work Exp  Salary  Distance  license  \
# 0   28    Male       0.0    0       4.0    14.3       3.2      0.0
# 1   23  Female       1.0    0       4.0     8.3       3.3      0.0
# 2   29    Male       1.0    0       7.0    13.4       4.1      0.0
# 3   28  Female       1.0    1       5.0    13.4       4.5      0.0
# 4   27    Male       1.0    0       4.0    13.4       4.6      0.0
#
#           Transport
# 0  Public Transport
# 1  Public Transport
# 2  Public Transport
# 3  Public Transport
# 4  Public Transport

# %%
df.shape
# Out:
# (444, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        444 non-null    int64
#  1   Gender     443 non-null    object
#  2   Engineer   442 non-null    float64
#  3   MBA        444 non-null    int64
#  4   Work Exp   443 non-null    float64
#  5   Salary     443 non-null    float64
#  6   Distance   444 non-null    float64
#  7   license    443 non-null    float64
#  8   Transport  444 non-null    object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 31.3+ KB

# %%
df.dtypes
# Out:
# Age            int64
# Gender        object
# Engineer     float64
# MBA            int64
# Work Exp     float64
# Salary       float64
# Distance     float64
# license      float64
# Transport     object
# dtype: object

# %%
df.describe()
# Out:
#               Age    Engineer         MBA    Work Exp      Salary    Distance  \
# count  444.000000  442.000000  444.000000  443.000000  443.000000  444.000000
# mean    27.747748    0.755656    0.252252    6.309255   16.216930   11.323198
# std      4.416710    0.430184    0.434795    5.113781   10.455554    3.606149
# min     18.000000    0.000000    0.000000    0.000000    6.500000    3.200000
# 25%     25.000000    1.000000    0.000000    3.000000    9.800000    8.800000
# 50%     27.000000    1.000000    0.000000    5.000000   13.600000   11.000000
# 75%     30.000000    1.000000    1.000000    8.000000   15.700000   13.425000
# max     43.000000    1.000000    1.000000   24.000000   57.000000   23.400000
#
#           license
# count  443.000000
# mean     0.234763
# std      0.424330
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %% [markdown]
# # checking for null's value

# %%
print("finding whether there is any nulls in the df  if yes how many  {}".format(df.isnull().sum().sum()))
# Out:
# finding whether there is any nulls in the df  if yes how many  6

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")          #to visualise wheather there is any null value
# Out:
# <AxesSubplot:>

# %%
df.dropna(inplace=True)
print("finding whether there is any nulls in after droping the df  if yes how many  {}".format(df.isnull().any().sum()))
# Out:
# finding whether there is any nulls in after droping the df  if yes how many  0

# %%
df.dropna(inplace=True)                                             #visualising after cleaning the null values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking for duplicates value

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory data analysis

# %%
df['Transport'].value_counts()
# Out:
# Public Transport     294
# Private Transport    144
# Name: Transport, dtype: int64

# %%
sns.countplot(df['Transport'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Transport', ylabel='count'>

# %%
sns.countplot(x="Gender",hue="Transport",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
# Public transport is the perfered mode of transport for both male & female

# %%
sns.countplot(x="Engineer",hue="Transport",data=df)
# Out:
# <AxesSubplot:xlabel='Engineer', ylabel='count'>

# %%
# Public transport is the perfered mode of transport for both engineer & non-engineer

# %%
sns.countplot(x="MBA",hue="Transport",data=df)
# Out:
# <AxesSubplot:xlabel='MBA', ylabel='count'>

# %%
# Public transport is the perfered mode of transport for both MBA & non-MBA

# %%
sns.countplot(x="license",hue="Transport",data=df)
# Out:
# <AxesSubplot:xlabel='license', ylabel='count'>

# %%
# Employees those who don't have driving license prefering public transport & viceversa

# %%
df['Age'].describe()
# Out:
# count    438.000000
# mean      27.760274
# std        4.421145
# min       18.000000
# 25%       25.000000
# 50%       27.000000
# 75%       30.000000
# max       43.000000
# Name: Age, dtype: float64

# %%
sns.histplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
# There is no outlier as the data for age is normally distributed,the mean being 27.76

# %%
df['Work Exp'].describe()
# Out:
# count    438.000000
# mean       6.303653
# std        5.124673
# min        0.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       24.000000
# Name: Work Exp, dtype: float64

# %%
sns.histplot(df['Work Exp'])
# Out:
# <AxesSubplot:xlabel='Work Exp', ylabel='Count'>

# %%
#

# %%
df['Salary'].describe()
# Out:
# count    438.000000
# mean      16.272146
# std       10.496908
# min        6.500000
# 25%        9.800000
# 50%       13.600000
# 75%       15.775000
# max       57.000000
# Name: Salary, dtype: float64

# %%
sns.histplot(df['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Count'>

# %%
#

# %%
df['Distance'].describe()
# Out:
# count    438.000000
# mean      11.376941
# std        3.598225
# min        3.200000
# 25%        8.900000
# 50%       11.050000
# 75%       13.500000
# max       23.400000
# Name: Distance, dtype: float64

# %%
sns.histplot(df['Distance'])
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='Count'>

# %%
#

# %% [markdown]
# # creating dummies for categorical value

# %%
Gender1=pd.get_dummies(df["Gender"],drop_first =True)
Gender1.head()
# Out:
#    Male
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1

# %%
Transport1=pd.get_dummies(df["Transport"],drop_first =True)
Transport1.head()
# Out:
#    Public Transport
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
df =pd.concat([df,Gender1,Transport1],axis=1)
df.head()
# Out:
#    Age  Gender  Engineer  MBA  Work Exp  Salary  Distance  license  \
# 0   28    Male       0.0    0       4.0    14.3       3.2      0.0
# 1   23  Female       1.0    0       4.0     8.3       3.3      0.0
# 2   29    Male       1.0    0       7.0    13.4       4.1      0.0
# 3   28  Female       1.0    1       5.0    13.4       4.5      0.0
# 4   27    Male       1.0    0       4.0    13.4       4.6      0.0
#
#           Transport  Male  Public Transport
# 0  Public Transport     1                 1
# 1  Public Transport     0                 1
# 2  Public Transport     1                 1
# 3  Public Transport     0                 1
# 4  Public Transport     1                 1

# %%
df.drop(["Gender","Transport"],axis=1,inplace=True)
df.head()
# Out:
#    Age  Engineer  MBA  Work Exp  Salary  Distance  license  Male  \
# 0   28       0.0    0       4.0    14.3       3.2      0.0     1
# 1   23       1.0    0       4.0     8.3       3.3      0.0     0
# 2   29       1.0    0       7.0    13.4       4.1      0.0     1
# 3   28       1.0    1       5.0    13.4       4.5      0.0     0
# 4   27       1.0    0       4.0    13.4       4.6      0.0     1
#
#    Public Transport
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %% [markdown]
# # Split the Data & fit the model

# %%
df.head()
# Out:
#    Age  Engineer  MBA  Work Exp  Salary  Distance  license  Male  \
# 0   28       0.0    0       4.0    14.3       3.2      0.0     1
# 1   23       1.0    0       4.0     8.3       3.3      0.0     0
# 2   29       1.0    0       7.0    13.4       4.1      0.0     1
# 3   28       1.0    1       5.0    13.4       4.5      0.0     0
# 4   27       1.0    0       4.0    13.4       4.6      0.0     1
#
#    Public Transport
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
X = df.drop('Public Transport',axis=1)

Y = df['Public Transport']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.30, random_state=123)

# %%
X_train.head()
# Out:
#      Age  Engineer  MBA  Work Exp  Salary  Distance  license  Male
# 144   28       0.0    0       6.0    13.7       9.4      0.0     0
# 206   26       1.0    0       2.0     9.8      10.7      0.0     0
# 163   28       1.0    0       6.0    13.6       9.7      1.0     1
# 287   29       0.0    0       7.0    14.7      12.3      0.0     1
# 176   36       0.0    0      17.0    39.0      10.0      1.0     1

# %%
# Scaling the X_train & X_test

from sklearn.preprocessing import StandardScaler

ss = StandardScaler() 

X_train_scaled = pd.DataFrame(ss.fit_transform(X_train) , columns = X_train.columns) 


X_test_scaled = pd.DataFrame(ss.transform(X_test) , columns = X_test.columns)

# %%
# Model Train

from sklearn.neural_network import MLPClassifier

nncl = MLPClassifier(max_iter=2000, 
                     verbose = True , 
                     hidden_layer_sizes= (100,100,100), 
                     activation='logistic' , 
                     solver = 'sgd' , 
                     batch_size=100, 
                     learning_rate='invscaling',
                     learning_rate_init = 0.001,
                     tol=.00001)

# %%
nncl.fit(X_train_scaled,Y_train)
# Out:
# Iteration 1, loss = 0.72673470
# Iteration 2, loss = 0.70915439
# Iteration 3, loss = 0.69772845
# Iteration 4, loss = 0.69010291
# Iteration 5, loss = 0.68511074
# Iteration 6, loss = 0.68131234
# Iteration 7, loss = 0.67862225
# Iteration 8, loss = 0.67671032
# Iteration 9, loss = 0.67522001
# Iteration 10, loss = 0.67400448
# Iteration 11, loss = 0.67315361
# Iteration 12, loss = 0.67246041
# Iteration 13, loss = 0.67194030
# Iteration 14, loss = 0.67141984
# Iteration 15, loss = 0.67091667
# Iteration 16, loss = 0.67048776
# Iteration 17, loss = 0.67009822
# Iteration 18, loss = 0.66974551
# Iteration 19, loss = 0.66943298
# Iteration 20, loss = 0.66906710
# Iteration 21, loss = 0.66868730
# Iteration 22, loss = 0.66833463
# Iteration 23, loss = 0.66800925
# Iteration 24, loss = 0.66768752
# Iteration 25, loss = 0.66741346
# Iteration 26, loss = 0.66710443
# Iteration 27, loss = 0.66686339
# Iteration 28, loss = 0.66662450
# Iteration 29, loss = 0.66640495
# ...

# %%
nncl.score(X_train_scaled,Y_train)
# Out:
# 0.6895424836601307

# %%
nncl.score(X_test_scaled,Y_test)
# Out:
# 0.6287878787878788

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
y_pred_train = nncl.predict(X_train_scaled)
y_pred_test = nncl.predict(X_test_scaled)

print(classification_report(Y_train,y_pred_train))
print(classification_report(Y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        95
#            1       0.69      1.00      0.82       211
#
#     accuracy                           0.69       306
#    macro avg       0.34      0.50      0.41       306
# weighted avg       0.48      0.69      0.56       306
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        49
#            1       0.63      1.00      0.77        83
#
#     accuracy                           0.63       132
#    macro avg       0.31      0.50      0.39       132
# weighted avg       0.40      0.63      0.49       132
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
nncl = MLPClassifier(max_iter=2000, 
                     verbose = True , 
                     hidden_layer_sizes= (100,), 
                     activation='relu' , 
                     solver = 'adam' , 
                     batch_size='auto', 
                     learning_rate='invscaling',
                     learning_rate_init = 0.001,
                     tol=.00001)

# %%
nncl.fit(X_train_scaled,Y_train)
# Out:
# Iteration 1, loss = 0.65071665
# Iteration 2, loss = 0.62981517
# Iteration 3, loss = 0.61137189
# Iteration 4, loss = 0.59366207
# Iteration 5, loss = 0.57817586
# Iteration 6, loss = 0.56387156
# Iteration 7, loss = 0.55099078
# Iteration 8, loss = 0.53910306
# Iteration 9, loss = 0.52826414
# Iteration 10, loss = 0.51865551
# Iteration 11, loss = 0.50959372
# Iteration 12, loss = 0.50151530
# Iteration 13, loss = 0.49391953
# Iteration 14, loss = 0.48744021
# Iteration 15, loss = 0.48117205
# Iteration 16, loss = 0.47543526
# Iteration 17, loss = 0.46973558
# Iteration 18, loss = 0.46460247
# Iteration 19, loss = 0.46007049
# Iteration 20, loss = 0.45523845
# Iteration 21, loss = 0.45100376
# Iteration 22, loss = 0.44682593
# Iteration 23, loss = 0.44271924
# Iteration 24, loss = 0.43889716
# Iteration 25, loss = 0.43531433
# Iteration 26, loss = 0.43171628
# Iteration 27, loss = 0.42831361
# Iteration 28, loss = 0.42505430
# Iteration 29, loss = 0.42228954
# ...

# %%
print(nncl.score(X_train_scaled,Y_train))
print(nncl.score(X_test_scaled,Y_test))
# Out:
# 0.9575163398692811
# 0.7878787878787878

# %%
nncl = MLPClassifier(max_iter=2000, 
                     verbose = True , 
                     hidden_layer_sizes= (100,), 
                     activation='relu' , 
                     solver = 'adam' , 
                     batch_size='auto', 
                     learning_rate='adaptive',
                     learning_rate_init = 0.01,
                     tol=.0001)

# %%
nncl.fit(X_train_scaled,Y_train)
# Out:
# Iteration 1, loss = 0.72452620
# Iteration 2, loss = 0.54416212
# Iteration 3, loss = 0.47324871
# Iteration 4, loss = 0.45123734
# Iteration 5, loss = 0.43900275
# Iteration 6, loss = 0.42310997
# Iteration 7, loss = 0.40784347
# Iteration 8, loss = 0.39293388
# Iteration 9, loss = 0.38062612
# Iteration 10, loss = 0.37149257
# Iteration 11, loss = 0.36772298
# Iteration 12, loss = 0.36656852
# Iteration 13, loss = 0.36385835
# Iteration 14, loss = 0.36015922
# Iteration 15, loss = 0.35560542
# Iteration 16, loss = 0.35056044
# Iteration 17, loss = 0.34817147
# Iteration 18, loss = 0.34381969
# Iteration 19, loss = 0.34077629
# Iteration 20, loss = 0.33769919
# Iteration 21, loss = 0.33527042
# Iteration 22, loss = 0.33255876
# Iteration 23, loss = 0.32995618
# Iteration 24, loss = 0.32709108
# Iteration 25, loss = 0.32428859
# Iteration 26, loss = 0.32140663
# Iteration 27, loss = 0.31875405
# Iteration 28, loss = 0.31827251
# Iteration 29, loss = 0.31585219
# ...

# %%
print(nncl.score(X_train_scaled,Y_train))
print(nncl.score(X_test_scaled,Y_test))
# Out:
# 0.9901960784313726
# 0.7803030303030303

# %%
nncl = MLPClassifier(max_iter=2000, verbose = True )

# %%
nncl.fit(X_train_scaled,Y_train)
# Out:
# Iteration 1, loss = 0.70674489
# Iteration 2, loss = 0.68371351
# Iteration 3, loss = 0.66336874
# Iteration 4, loss = 0.64405313
# Iteration 5, loss = 0.62632264
# Iteration 6, loss = 0.60901196
# Iteration 7, loss = 0.59445464
# Iteration 8, loss = 0.58004271
# Iteration 9, loss = 0.56709609
# Iteration 10, loss = 0.55553475
# Iteration 11, loss = 0.54450654
# Iteration 12, loss = 0.53410471
# Iteration 13, loss = 0.52528815
# Iteration 14, loss = 0.51672565
# Iteration 15, loss = 0.50874456
# Iteration 16, loss = 0.50147025
# Iteration 17, loss = 0.49468908
# Iteration 18, loss = 0.48848939
# Iteration 19, loss = 0.48278879
# Iteration 20, loss = 0.47738924
# Iteration 21, loss = 0.47201768
# Iteration 22, loss = 0.46703634
# Iteration 23, loss = 0.46286093
# Iteration 24, loss = 0.45826294
# Iteration 25, loss = 0.45451904
# Iteration 26, loss = 0.45037480
# Iteration 27, loss = 0.44689657
# Iteration 28, loss = 0.44329809
# Iteration 29, loss = 0.44005870
# ...

# %%
print(nncl.score(X_train_scaled,Y_train))
print(nncl.score(X_test_scaled,Y_test))
# Out:
# 0.9509803921568627
# 0.7727272727272727
